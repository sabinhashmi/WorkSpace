# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import MinMaxScaler


# from DataProduction import dataProd

import warnings
warnings.filterwarnings('ignore')

# Initialize scaler
scaler = MinMaxScaler(feature_range=(0, 1))

# Data production and loading
run_list = [285490, 286498, 287987, 288543, 289413, 289733, 291970, 293528]
planes_list = ['UTaX', 'UTaU', 'UTbV', 'UTbX']

# dataProduction = dataProd()
# mix_ = dataProduction.multipleRun(*run_list)
# mix = mix_.copy()

import random
random.seed(46)

from scipy.special import kl_div,softmax

sns.set(
    context='notebook',  # 'paper', 'notebook', 'talk', 'poster'
    style='darkgrid',   # 'darkgrid', 'whitegrid', 'dark', 'white', 'ticks'
    palette='deep',      # Color palette
    font='sans-serif',   # Font family
    font_scale=0.75,      # Font scale
    rc={'figure.figsize': (12, 6)}  # Default figure size
)


def colorCodes(div_value):

    if div_value < 0.1:
        color = 'green'
    elif (div_value > 0.1) & (div_value<0.6):
        color = 'orange'
    else:
        color = 'red'
    return f'background-color: {color}'

# %% [markdown]
# ### Simulation Data Generation.

# %%
class simData():

    def __init__(self,num_chips,pseudo_random):

        np.random.seed(pseudo_random)
        self.num_chips = num_chips

        chips = {}
        for i in range(self.num_chips): #One side of 1024 chips [512]
            chips[f'chip{i+1}'] = np.random.laplace(loc=0.0, scale=1.0, size=128) # For 1 Plane, 1024 ASICS, 128 Channel Each

        self.all_chips_pedestals = pd.DataFrame(chips)

        # return self.all_chips_pedestals

    def pedestals_data(self):
        return self.all_chips_pedestals

    def chip_average(self):
        self.average_pedestal_per_chip = np.mean(self.all_chips_pedestals,axis=0).values#.reshape(int(self.num_chips/16),16)

        return self.average_pedestal_per_chip

# %%
num_chips = 16#Easy Visualisation

# %%
benchmark_data = simData(num_chips,27).chip_average()

benchmark_probability = softmax(benchmark_data)


kl_div_data=pd.DataFrame(index=np.arange(1,num_chips+1))

kl_div_data['BenchmarkScore'] = kl_div(benchmark_probability,benchmark_probability)

# %%
#KL-Divergence for Similar Distribution

test_1_laplacian = simData(num_chips,55).chip_average()

test_1_laplacian_probability = softmax(test_1_laplacian)

kl_div_data['Similar Distributions - [Test1]']  = np.round(kl_div(benchmark_probability,test_1_laplacian_probability),3)

# %%
#KL-Divergence for Data with Random Outliers

test_2_outliers = benchmark_data.copy()

test_2_outliers[np.random.randint(num_chips,size=12)]=test_2_outliers[np.random.randint(num_chips,size=12)]+10

test_2_outliers_probability = softmax(test_2_outliers)

kl_div_data['Data with Random Outliers - [Test2]']  = np.round(kl_div(benchmark_probability,test_2_outliers_probability),3)

# %%
#KL-Divergence for Data with Large Outliers

test_3_large_outliers = benchmark_data.copy()

test_3_large_outliers[np.random.randint(num_chips,size=12)]=test_3_large_outliers[np.random.randint(num_chips,size=12)]+20

test_3_large_outliers_probability = softmax(test_3_large_outliers)

kl_div_data['Data with Large Outliers - [Test3]']  = np.round(kl_div(benchmark_probability,test_3_large_outliers_probability),3)

# %%
#KL-Divergence for Data with Zero Value Distribution

test_4_zeros = np.zeros(num_chips)

test_4_zeros_probability = softmax(test_4_zeros)

kl_div_data['Data with Zero Values - [Test4]']  = np.round(kl_div(benchmark_probability,test_4_zeros_probability),3)

# %%
#KL-Divergence for Data with Back Ground Noise

test_5_w_noise = benchmark_data.copy()

test_5_w_noise=test_5_w_noise + np.random.normal(0,1,num_chips)

test_5_w_noise_probability = softmax(test_5_w_noise)

kl_div_data['Data with Background Noise - [Test5]']  = np.round(kl_div(benchmark_probability,test_5_w_noise_probability),3)

# %%
#KL-Divergence for Data with Systematic Shift

test_6_w_syst_shift = benchmark_data.copy()

test_6_w_syst_shift= 2 * test_6_w_syst_shift

test_6_w_syst_shift_probability = softmax(test_6_w_syst_shift)

kl_div_data['Data with Systematic Shift - [Test6]']  = np.round(kl_div(benchmark_probability,test_6_w_syst_shift_probability),3)

# %%
kl_div_data.style.applymap(colorCodes)
# Out:
# <style type="text/css">
# #T_93c90_row0_col0, #T_93c90_row0_col1, #T_93c90_row0_col3, #T_93c90_row0_col4, #T_93c90_row0_col5, #T_93c90_row0_col6, #T_93c90_row1_col0, #T_93c90_row1_col1, #T_93c90_row1_col2, #T_93c90_row1_col3, #T_93c90_row1_col4, #T_93c90_row1_col5, #T_93c90_row1_col6, #T_93c90_row2_col0, #T_93c90_row2_col1, #T_93c90_row2_col2, #T_93c90_row2_col4, #T_93c90_row2_col6, #T_93c90_row3_col0, #T_93c90_row3_col1, #T_93c90_row3_col3, #T_93c90_row3_col4, #T_93c90_row3_col5, #T_93c90_row3_col6, #T_93c90_row4_col0, #T_93c90_row4_col1, #T_93c90_row4_col2, #T_93c90_row4_col4, #T_93c90_row4_col5, #T_93c90_row4_col6, #T_93c90_row5_col0, #T_93c90_row5_col1, #T_93c90_row5_col2, #T_93c90_row5_col3, #T_93c90_row5_col4, #T_93c90_row5_col5, #T_93c90_row5_col6, #T_93c90_row6_col0, #T_93c90_row6_col1, #T_93c90_row6_col3, #T_93c90_row6_col4, #T_93c90_row6_col5, #T_93c90_row6_col6, #T_93c90_row7_col0, #T_93c90_row7_col1, #T_93c90_row7_col2, #T_93c90_row7_col3, #T_93c90_row7_col4, #T_93c90_row7_col5, #T_93c90_row7_col6, #T_93c90_row8_col0, #T_93c90_row8_col1, #T_93c90_row8_col3, #T_93c90_row8_col4, #T_93c90_row8_col5, #T_93c90_row8_col6, #T_93c90_row9_col0, #T_93c90_row9_col1, #T_93c90_row9_col2, #T_93c90_row9_col4, #T_93c90_row9_col5, #T_93c90_row9_col6, #T_93c90_row10_col0, #T_93c90_row10_col1, #T_93c90_row10_col2, #T_93c90_row10_col4, #T_93c90_row10_col5, #T_93c90_row10_col6, #T_93c90_row11_col0, #T_93c90_row11_col1, #T_93c90_row11_col2, #T_93c90_row11_col4, #T_93c90_row11_col5, #T_93c90_row11_col6, #T_93c90_row12_col0, #T_93c90_row12_col1, #T_93c90_row12_col2, #T_93c90_row12_col4, #T_93c90_row12_col5, #T_93c90_row12_col6, #T_93c90_row13_col0, #T_93c90_row13_col1, #T_93c90_row13_col3, #T_93c90_row13_col4, #T_93c90_row13_col5, #T_93c90_row13_col6, #T_93c90_row14_col0, #T_93c90_row14_col1, #T_93c90_row14_col2, #T_93c90_row14_col4, #T_93c90_row14_col5, #T_93c90_row14_col6, #T_93c90_row15_col0, #T_93c90_row15_col1, #T_93c90_row15_col2, #T_93c90_row15_col3, #T_93c90_row15_col4, #T_93c90_row15_col5, #T_93c90_row15_col6 {
#   background-color: green;
# }
# #T_93c90_row0_col2, #T_93c90_row2_col3, #T_93c90_row4_col3, #T_93c90_row9_col3, #T_93c90_row10_col3, #T_93c90_row11_col3, #T_93c90_row12_col3, #T_93c90_row14_col3 {
#   background-color: red;
# }
# #T_93c90_row2_col5, #T_93c90_row3_col2, #T_93c90_row6_col2, #T_93c90_row8_col2, #T_93c90_row13_col2 {
#   background-color: orange;
# }
# </style>
# <table id="T_93c90">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93c90_level0_col0" class="col_heading level0 col0" >BenchmarkScore</th>
#       <th id="T_93c90_level0_col1" class="col_heading level0 col1" >Similar Distributions - [Test1]</th>
#       <th id="T_93c90_level0_col2" class="col_heading level0 col2" >Data with Random Outliers - [Test2]</th>
#       <th id="T_93c90_level0_col3" class="col_heading level0 col3" >Data with Large Outliers - [Test3]</th>
#       <th id="T_93c90_level0_col4" class="col_heading level0 col4" >Data with Zero Values - [Test4]</th>
#       <th id="T_93c90_level0_col5" class="col_heading level0 col5" >Data with Background Noise - [Test5]</th>
#       <th id="T_93c90_level0_col6" class="col_heading level0 col6" >Data with Systematic Shift - [Test6]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93c90_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_93c90_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_93c90_row0_col1" class="data row0 col1" >0.001000</td>
#       <td id="T_93c90_row0_col2" class="data row0 col2" >0.628000</td>
#       <td id="T_93c90_row0_col3" class="data row0 col3" >0.018000</td>
#       <td id="T_93c90_row0_col4" class="data row0 col4" >0.001000</td>
#       <td id="T_93c90_row0_col5" class="data row0 col5" >0.005000</td>
#       <td id="T_93c90_row0_col6" class="data row0 col6" >0.001000</td>
#     </tr>
#     <tr>
#       <th id="T_93c90_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_93c90_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_93c90_row1_col1" class="data row1 col1" >0.005000</td>
#       <td id="T_93c90_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_93c90_row1_col3" class="data row1 col3" >0.005000</td>
#       <td id="T_93c90_row1_col4" class="data row1 col4" >0.001000</td>
#       <td id="T_93c90_row1_col5" class="data row1 col5" >0.092000</td>
#       <td id="T_93c90_row1_col6" class="data row1 col6" >0.001000</td>
#     </tr>
#     <tr>
#       <th id="T_93c90_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_93c90_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_93c90_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_93c90_row2_col2" class="data row2 col2" >0.015000</td>
#       <td id="T_93c90_row2_col3" class="data row2 col3" >1.075000</td>
#       <td id="T_93c90_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_93c90_row2_col5" class="data row2 col5" >0.139000</td>
#       <td id="T_93c90_row2_col6" class="data row2 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_93c90_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_93c90_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_93c90_row3_col1" class="data row3 col1" >0.003000</td>
#       <td id="T_93c90_row3_col2" class="data row3 col2" >0.419000</td>
#       <td id="T_93c90_row3_col3" class="data row3 col3" >0.017000</td>
#       <td id="T_93c90_row3_col4" class="data row3 col4" >0.002000</td>
#       <td id="T_93c90_row3_col5" class="data row3 col5" >0.003000</td>
#       <td id="T_93c90_row3_col6" class="data row3 col6" >0.002000</td>
#     </tr>
#     <tr>
#       <th id="T_93c90_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_93c90_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_93c90_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_93c90_row4_col2" class="data row4 col2" >0.001000</td>
#       <td id="T_93c90_row4_col3" class="data row4 col3" >1.048000</td>
#       <td id="T_93c90_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_93c90_row4_col5" class="data row4 col5" >0.029000</td>
#       <td id="T_93c90_row4_col6" class="data row4 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_93c90_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_93c90_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_93c90_row5_col1" class="data row5 col1" >0.001000</td>
#       <td id="T_93c90_row5_col2" class="data row5 col2" >0.006000</td>
#       <td id="T_93c90_row5_col3" class="data row5 col3" >0.015000</td>
#       <td id="T_93c90_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_93c90_row5_col5" class="data row5 col5" >0.043000</td>
#       <td id="T_93c90_row5_col6" class="data row5 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_93c90_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_93c90_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_93c90_row6_col1" class="data row6 col1" >0.003000</td>
#       <td id="T_93c90_row6_col2" class="data row6 col2" >0.596000</td>
#       <td id="T_93c90_row6_col3" class="data row6 col3" >0.008000</td>
#       <td id="T_93c90_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_93c90_row6_col5" class="data row6 col5" >0.025000</td>
#       <td id="T_93c90_row6_col6" class="data row6 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_93c90_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_93c90_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_93c90_row7_col1" class="data row7 col1" >0.003000</td>
#       <td id="T_93c90_row7_col2" class="data row7 col2" >0.006000</td>
#       <td id="T_93c90_row7_col3" class="data row7 col3" >0.012000</td>
#       <td id="T_93c90_row7_col4" class="data row7 col4" >0.000000</td>
#       <td id="T_93c90_row7_col5" class="data row7 col5" >0.000000</td>
#       <td id="T_93c90_row7_col6" class="data row7 col6" >0.001000</td>
#     </tr>
#     <tr>
#       <th
